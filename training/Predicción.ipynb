# %% [markdown]
# #### 1. Librerias y configuraciones previas

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# Preprocesado y modelado
# ==============================================================================

from scipy.stats import pearsonr
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
#Escalar Variables
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
import math

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

#Reducción de dimensionalidad
from sklearn.decomposition import PCA

#Creacion de los modelos
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

#Creacion de los modelos bayesianos
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB

#Creacion de los modelos KNN vs Gaussian
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB

from sklearn.linear_model import LogisticRegression

# Preprocesado y modelado Maquina de vector de soporte
# ==============================================================================
from scipy.stats import pearsonr
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import math

# Preprocesado y modelado Random Forest
# ==============================================================================

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder


#creación de modelos Random Forest
from sklearn.ensemble import RandomForestClassifier


#import statsmodels.api as sm Random Forest
import math
import statsmodels.api as sm


#evaluacion de variables
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing

#Escalar Variables
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import LocalOutlierFactor # Algoritmo LOF

import statsmodels.api as sm
import math

#from sklearn.svm import LinearSVC

from sklearn import svm
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

from sklearn.linear_model import LogisticRegression

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# Permitir ver todas las filas y columnas
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# #### 2. Carga del dataset

# %%
df_tenis=pd.read_csv('../resources/data/tennis_matches.csv')
df_tenis.info() # Se comprueba que el archivo contenga los datos, los nombres de las columnas y el tipo de dato de cada columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169690 entries, 0 to 169689
# Data columns (total 49 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   best_of             169690 non-null  int64
#  1   draw_size           1232 non-null    float64
#  2   l_1stIn             83415 non-null   float64
#  3   l_1stWon            83415 non-null   float64
#  4   l_2ndWon            83415 non-null   float64
#  5   l_SvGms             83415 non-null   float64
#  6   l_ace               83415 non-null   float64
#  7   l_bpFaced           83415 non-null   float64
#  8   l_bpSaved           83415 non-null   float64
#  9   l_df                83415 non-null   float64
#  10  l_svpt              83415 non-null   float64
#  11  loser_age           164700 non-null  float64
#  12  loser_entry         25339 non-null   object
#  13  loser_hand          169605 non-null  object
#  14  loser_ht            139052 non-null  float64
#  15  loser_id            169690 non-null  int64
#  16  loser_ioc           169690 non-null  object
#  17  loser_name          169690 non-null  object
#  18  loser_rank          145909 non-null  float64
#  19  loser_rank_points   93025 non-null   float64
#  20  loser_seed          32853 non-null   float64
#  21  match_num           169690 non-null  int64
#  22  minutes             82103 non-null   float64
#  23  round               169690 non-null  object
#  24  score               169514 non-null  object
#  25  surface             167151 non-null  object
#  26  tourney_date        169690 non-null  int64
#  27  tourney_id          169690 non-null  object
#  28  tourney_level       169690 non-null  object
#  29  tourney_name        169690 non-null  object
#  30  w_1stIn             83415 non-null   float64
#  31  w_1stWon            83415 non-null   float64
#  32  w_2ndWon            83415 non-null   float64
#  33  w_SvGms             83415 non-null   float64
#  34  w_ace               83415 non-null   float64
#  35  w_bpFaced           83415 non-null   float64
#  36  w_bpSaved           83415 non-null   float64
#  37  w_df                83415 non-null   float64
#  38  w_svpt              83415 non-null   float64
#  39  winner_age          167929 non-null  float64
#  40  winner_entry        14748 non-null   object
#  41  winner_hand         169651 non-null  object
#  42  winner_ht           150884 non-null  float64
#  43  winner_id           169690 non-null  int64
#  44  winner_ioc          169690 non-null  object
#  45  winner_name         169690 non-null  object
#  46  winner_rank         149773 non-null  float64
#  47  winner_rank_points  94291 non-null   float64
#  48  winner_seed         65295 non-null   float64
# dtypes: float64(30), int64(5), object(14)
# memory usage: 63.4+ MB

# %% [markdown]
# #### 3. Limpieza de datos y preparación

# %% [markdown]
# Revisando los tipos de datos se evidencia que hay 5 variables de tipo entero, 14 de tipo string y 30 de tipo flotante. Asimismo en todas las variables menos en 13 existen registros faltantes.

# %%
df_tenis["Anio"]=df_tenis["tourney_date"].astype("str").str[:4].astype("int") #Se crea una columna con el año del torneo
df_tenis["Anio_agrupado"]=df_tenis[["Anio"]].apply(lambda x: "1960-1980" if (x["Anio"]<=1980) else "1981-1991" if (x["Anio"]<=1991) else "1992-2019", axis=1) #Se crea una nueva columna con el fin de agrupar por años 
df_tenis.groupby("Anio_agrupado")["l_1stIn"].count().to_frame().plot.bar(figsize=(10,5),color="b",ylabel="Número de registros no nulos",xlabel="Rango de fechas", title="Número de registros no nulos de l_1sIn por años") #Se crea un gráfico de barr
# Out:
# <AxesSubplot:title={'center':'Número de registros no nulos de l_1sIn por años'}, xlabel='Rango de fechas', ylabel='Número de registros no nulos'>

# %% [markdown]
# Cuando se grafica por años se evidencia que la mayor cantidad de datos no nulos que hay en la base están desde el año 1992, estando en línea con la descripción del dataset donde se indica que las estadísticas del partido sólo están disponibles desde al año 1991. Por lo tanto se toma la decisión de eliminar los datos de años inferiores a 1992.

# %%
df_tenis=df_tenis[df_tenis["Anio"]>=1992]  #Se mantienen en la base de datos los registros de años superiores a 1991
df_tenis.drop(["Anio","Anio_agrupado"], axis=1 , inplace=True) #Se eliminan las columnas creadas anteriormente

# %% [markdown]
# También, se decide trabajar únicamente con datos de partidos entre jugadores rankeados entre los 100 primeros del mundo y sólo en torneos de categoría G, M o A por lo que se eliminarán también los registros que no correspondan con ello.

# %%
df_tenis=df_tenis[(df_tenis["loser_rank"]<=100) & (df_tenis["winner_rank"]<=100)& (df_tenis["tourney_level"]=="G") | (df_tenis["tourney_level"]=="M") | (df_tenis["tourney_level"]=="A")] #Se excluyen los registros que no correspondan a jugadores del top 100 y ni torneos diferentes a G, M o A.
df_tenis.shape  #Tamaño del dataframe.
# Out:
# (74918, 49)

# %% [markdown]
# El nuevo dataset contiene 74.918 filas y 49 columnas

# %%
# Revisión de duplicados
df_tenis.loc[df_tenis.duplicated()]
# Out:
# Empty DataFrame
# Columns: [best_of, draw_size, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_ace, l_bpFaced, l_bpSaved, l_df, l_svpt, loser_age, loser_entry, loser_hand, loser_ht, loser_id, loser_ioc, loser_name, loser_rank, loser_rank_points, loser_seed, match_num, minutes, round, score, surface, tourney_date, tourney_id, tourney_level, tourney_name, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_ace, w_bpFaced, w_bpSaved, w_df, w_svpt, winner_age, winner_entry, winner_hand, winner_ht, winner_id, winner_ioc, winner_name, winner_rank, winner_rank_points, winner_seed]
# Index: []

# %% [markdown]
# No se evidencian registros duplicados en el dataset y se indagará acerca de los registros nulos que aún están en el mismo.

# %%
# Se reemplaza los valores "?" por np.nan
df_tenis.replace('?',np.nan, inplace=True) 
# Crear DataFrame para almacenar información
null_counts = pd.DataFrame({'columna': df_tenis.columns, 'cantidad_nulos': df_tenis.isnull().sum()})

# Imprimir información con los valores nulos por columna de aquellas con mayor cantidad de nulos
null_counts.sort_values("cantidad_nulos", ascending=False, inplace=True)
null_counts.head(15)
# Out:
#                    columna  cantidad_nulos
# draw_size        draw_size           74918
# winner_entry  winner_entry           65694
# loser_entry    loser_entry           59889
# loser_seed      loser_seed           55740
# winner_seed    winner_seed           40782
# loser_ht          loser_ht            3665
# minutes            minutes            2380
# winner_ht        winner_ht            2103
# w_2ndWon          w_2ndWon            1176
# w_SvGms            w_SvGms            1176
# w_ace                w_ace            1176
# w_bpFaced        w_bpFaced            1176
# w_bpSaved        w_bpSaved            1176
# w_df                  w_df            1176
# w_svpt              w_svpt            1176

# %% [markdown]
# Se encuentra que la mayor cantidad de registros nulos se dan en 3 variables: draw_size, entry y seed. Ninguna de ellas corresponde a estadísticas propias del desempeño de los jugadores en el partido y se considera que son datos que no aportarían valor al modelo de clasificación por lo que se decide eliminar dichas variables. Además, en muchas columnas se evidencia la misma cantidad de datos nulos (1176) lo cual indica que no hay valores en todas esas líneas por lo que se excluyen también del set de datos ya que no aportan valor al modelo al no tener información.

# %%
df_tenis.drop(["draw_size","winner_entry","loser_entry","loser_seed","winner_seed"], axis=1, inplace=True) # Se eliminan las columnas que no son necesarias

df_tenis.dropna(subset=['w_1stWon'], inplace=True)

# %% [markdown]
# Se eliminan las columnas y se verifican nuevamente los registros nulos restantes.

# %%
# Se reemplaza los valores "?" por np.nan
df_tenis.replace('?',np.nan, inplace=True) 
# Crear DataFrame para almacenar información
null_counts = pd.DataFrame({'columna': df_tenis.columns, 'cantidad_nulos': df_tenis.isnull().sum()})

# Imprimir información con los valores nulos por columna de aquellas con mayor cantidad de nulos
null_counts.sort_values("cantidad_nulos", ascending=False, inplace=True)
null_counts[null_counts["cantidad_nulos"]>0]
# Out:
#                                columna  cantidad_nulos
# loser_ht                      loser_ht            3648
# winner_ht                    winner_ht            2091
# minutes                        minutes            1215
# loser_rank_points    loser_rank_points             963
# winner_rank_points  winner_rank_points             803
# loser_rank                  loser_rank             230
# winner_rank                winner_rank              62
# loser_age                    loser_age              25
# winner_age                  winner_age               1
# score                            score               1

# %% [markdown]
# Los registros restantes con valores nulos se consideran no representativos por lo que se decide eliminarlos

# %%
df_tenis.dropna(inplace=True) #Se eliminan los registros nulos restantes en el dataset

# %%
# Se reemplaza los valores "?" por np.nan
df_tenis.replace('?',np.nan, inplace=True) 
# Crear DataFrame para almacenar información
null_counts = pd.DataFrame({'columna': df_tenis.columns, 'cantidad_nulos': df_tenis.isnull().sum()})

# Imprimir información con los valores nulos por columna de aquellas con mayor cantidad de nulos
null_counts.sort_values("cantidad_nulos", ascending=False, inplace=True)
null_counts[null_counts["cantidad_nulos"]>0]
# Out:
# Empty DataFrame
# Columns: [columna, cantidad_nulos]
# Index: []

# %% [markdown]
# Al verificar nuevamente se evidencia que ya no existen registros nulos en la base de datos

# %% [markdown]
# ##### 3.1 Análisis de Correlación

# %%
corr = df_tenis.corr ()
corr.style.background_gradient (cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_5f94f_row0_col0, #T_5f94f_row1_col1, #T_5f94f_row2_col2, #T_5f94f_row3_col3, #T_5f94f_row4_col4, #T_5f94f_row5_col5, #T_5f94f_row6_col6, #T_5f94f_row7_col7, #T_5f94f_row8_col8, #T_5f94f_row9_col9, #T_5f94f_row10_col10, #T_5f94f_row11_col11, #T_5f94f_row12_col12, #T_5f94f_row13_col13, #T_5f94f_row14_col14, #T_5f94f_row15_col15, #T_5f94f_row16_col16, #T_5f94f_row17_col17, #T_5f94f_row18_col18, #T_5f94f_row19_col19, #T_5f94f_row20_col20, #T_5f94f_row21_col21, #T_5f94f_row22_col22, #T_5f94f_row23_col23, #T_5f94f_row24_col24, #T_5f94f_row25_col25, #T_5f94f_row26_col26, #T_5f94f_row27_col27, #T_5f94f_row28_col28, #T_5f94f_row29_col29, #T_5f94f_row30_col30, #T_5f94f_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col1, #T_5f94f_row0_col18 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5f94f_row0_col2, #T_5f94f_row24_col16 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_5f94f_row0_col3, #T_5f94f_row2_col25, #T_5f94f_row3_col25, #T_5f94f_row6_col26, #T_5f94f_row19_col25, #T_5f94f_row22_col1, #T_5f94f_row25_col1, #T_5f94f_row25_col16, #T_5f94f_row25_col18, #T_5f94f_row26_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_5f94f_row0_col4, #T_5f94f_row4_col23, #T_5f94f_row9_col0, #T_5f94f_row19_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_5f94f_row0_col5, #T_5f94f_row8_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5f94f_row0_col6, #T_5f94f_row6_col16, #T_5f94f_row16_col0, #T_5f94f_row24_col1, #T_5f94f_row25_col19 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5f94f_row0_col7, #T_5f94f_row0_col22, #T_5f94f_row8_col0, #T_5f94f_row16_col22, #T_5f94f_row25_col8, #T_5f94f_row25_col22 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5f94f_row0_col8, #T_5f94f_row1_col30, #T_5f94f_row2_col30, #T_5f94f_row4_col30, #T_5f94f_row6_col30, #T_5f94f_row14_col17, #T_5f94f_row14_col29, #T_5f94f_row28_col13 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5f94f_row0_col9, #T_5f94f_row9_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_5f94f_row0_col10, #T_5f94f_row1_col10, #T_5f94f_row1_col28, #T_5f94f_row2_col29, #T_5f94f_row4_col28, #T_5f94f_row10_col0, #T_5f94f_row12_col19, #T_5f94f_row18_col11, #T_5f94f_row19_col27, #T_5f94f_row27_col5, #T_5f94f_row27_col16, #T_5f94f_row27_col19, #T_5f94f_row28_col4, #T_5f94f_row28_col25, #T_5f94f_row31_col16 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col11, #T_5f94f_row6_col10, #T_5f94f_row7_col27, #T_5f94f_row10_col26, #T_5f94f_row14_col6, #T_5f94f_row15_col23, #T_5f94f_row22_col11, #T_5f94f_row22_col24, #T_5f94f_row27_col22, #T_5f94f_row30_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col12, #T_5f94f_row2_col12, #T_5f94f_row3_col15, #T_5f94f_row5_col24, #T_5f94f_row7_col5, #T_5f94f_row11_col4, #T_5f94f_row11_col8, #T_5f94f_row11_col21, #T_5f94f_row12_col0, #T_5f94f_row15_col5, #T_5f94f_row15_col28, #T_5f94f_row16_col10, #T_5f94f_row17_col22, #T_5f94f_row19_col12, #T_5f94f_row20_col15, #T_5f94f_row28_col15, #T_5f94f_row31_col28 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col13, #T_5f94f_row8_col24, #T_5f94f_row12_col16, #T_5f94f_row13_col31, #T_5f94f_row14_col30, #T_5f94f_row15_col9, #T_5f94f_row15_col16, #T_5f94f_row15_col26, #T_5f94f_row30_col14 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col14, #T_5f94f_row4_col8, #T_5f94f_row6_col18, #T_5f94f_row7_col18, #T_5f94f_row8_col26, #T_5f94f_row24_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5f94f_row0_col15, #T_5f94f_row8_col1, #T_5f94f_row20_col6, #T_5f94f_row24_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5f94f_row0_col16, #T_5f94f_row16_col7, #T_5f94f_row17_col27, #T_5f94f_row22_col9, #T_5f94f_row25_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5f94f_row0_col17, #T_5f94f_row1_col29, #T_5f94f_row2_col17, #T_5f94f_row2_col27, #T_5f94f_row4_col10, #T_5f94f_row5_col7, #T_5f94f_row7_col15, #T_5f94f_row10_col22, #T_5f94f_row11_col26, #T_5f94f_row14_col20, #T_5f94f_row14_col23, #T_5f94f_row15_col3, #T_5f94f_row15_col11, #T_5f94f_row18_col10, #T_5f94f_row19_col17, #T_5f94f_row19_col29, #T_5f94f_row21_col10, #T_5f94f_row22_col27, #T_5f94f_row29_col19, #T_5f94f_row31_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col19 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_5f94f_row0_col20, #T_5f94f_row4_col22, #T_5f94f_row5_col16, #T_5f94f_row6_col23, #T_5f94f_row8_col9, #T_5f94f_row15_col12, #T_5f94f_row17_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5f94f_row0_col21, #T_5f94f_row1_col3, #T_5f94f_row24_col18 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_5f94f_row0_col23, #T_5f94f_row3_col30, #T_5f94f_row6_col13, #T_5f94f_row8_col14, #T_5f94f_row18_col30, #T_5f94f_row25_col0, #T_5f94f_row26_col30, #T_5f94f_row27_col13 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_5f94f_row0_col24, #T_5f94f_row3_col13, #T_5f94f_row5_col13, #T_5f94f_row6_col25, #T_5f94f_row14_col16, #T_5f94f_row14_col19, #T_5f94f_row16_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col25, #T_5f94f_row15_col19, #T_5f94f_row19_col15, #T_5f94f_row24_col7, #T_5f94f_row29_col30 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5f94f_row0_col26, #T_5f94f_row20_col18, #T_5f94f_row20_col19 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5f94f_row0_col27, #T_5f94f_row3_col10, #T_5f94f_row3_col11, #T_5f94f_row9_col27, #T_5f94f_row11_col20, #T_5f94f_row12_col1, #T_5f94f_row20_col10, #T_5f94f_row20_col28, #T_5f94f_row21_col17, #T_5f94f_row26_col12, #T_5f94f_row26_col27, #T_5f94f_row27_col4, #T_5f94f_row28_col18, #T_5f94f_row28_col26, #T_5f94f_row29_col1, #T_5f94f_row29_col4, #T_5f94f_row31_col9, #T_5f94f_row31_col18, #T_5f94f_row31_col22 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col28, #T_5f94f_row1_col11, #T_5f94f_row4_col27, #T_5f94f_row4_col29, #T_5f94f_row9_col10, #T_5f94f_row9_col12, #T_5f94f_row10_col19, #T_5f94f_row11_col1, #T_5f94f_row11_col28, #T_5f94f_row12_col18, #T_5f94f_row12_col21, #T_5f94f_row18_col29, #T_5f94f_row21_col29, #T_5f94f_row26_col10, #T_5f94f_row27_col2, #T_5f94f_row28_col1, #T_5f94f_row31_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col29, #T_5f94f_row2_col10, #T_5f94f_row3_col28, #T_5f94f_row5_col10, #T_5f94f_row5_col29, #T_5f94f_row14_col3, #T_5f94f_row17_col5, #T_5f94f_row18_col12, #T_5f94f_row21_col28, #T_5f94f_row28_col21, #T_5f94f_row31_col27 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col30, #T_5f94f_row5_col15, #T_5f94f_row5_col23, #T_5f94f_row14_col5, #T_5f94f_row28_col17, #T_5f94f_row31_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5f94f_row0_col31, #T_5f94f_row5_col11, #T_5f94f_row12_col15, #T_5f94f_row21_col6, #T_5f94f_row22_col26, #T_5f94f_row25_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_5f94f_row1_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5f94f_row1_col2, #T_5f94f_row2_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_5f94f_row1_col4, #T_5f94f_row17_col12, #T_5f94f_row17_col29 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_5f94f_row1_col5, #T_5f94f_row3_col23, #T_5f94f_row15_col31, #T_5f94f_row20_col5, #T_5f94f_row21_col22, #T_5f94f_row24_col20, #T_5f94f_row25_col20 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5f94f_row1_col6, #T_5f94f_row1_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_5f94f_row1_col8, #T_5f94f_row5_col30, #T_5f94f_row7_col13, #T_5f94f_row10_col30, #T_5f94f_row14_col12, #T_5f94f_row20_col30, #T_5f94f_row31_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5f94f_row1_col9, #T_5f94f_row7_col6, #T_5f94f_row9_col1 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_5f94f_row1_col12, #T_5f94f_row5_col17, #T_5f94f_row11_col18, #T_5f94f_row14_col28, #T_5f94f_row15_col22 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_5f94f_row1_col13, #T_5f94f_row1_col15, #T_5f94f_row4_col15, #T_5f94f

# %% [markdown]
# Se eliminan las variables que presentan correlacion superior al 80% y aquellas otras que no son relevantes de cara al modelo

# %%
df_tenis= df_tenis.drop(["l_SvGms","w_SvGms","w_1stWon","l_1stWon","minutes","l_svpt","w_svpt","l_bpSaved","w_bpSaved","l_1stIn","w_1stIn","loser_ioc","tourney_date","loser_id","winner_id","match_num","winner_rank_points","loser_rank_points","best_of","tourney_id","tourney_name","winner_ioc","round","score"], axis=1) # Se eliminan las variables que presentan una alta correlacion así como las variables que no aportan información relevante de cara a lo que se quiere predecir como el id del jugador, rank_points_match_num, best_of

# %%
corr = df_tenis.corr ()
corr.style.background_gradient (cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_11bcd_row0_col0, #T_11bcd_row1_col1, #T_11bcd_row2_col2, #T_11bcd_row3_col3, #T_11bcd_row4_col4, #T_11bcd_row5_col5, #T_11bcd_row6_col6, #T_11bcd_row7_col7, #T_11bcd_row8_col8, #T_11bcd_row9_col9, #T_11bcd_row10_col10, #T_11bcd_row11_col11, #T_11bcd_row12_col12, #T_11bcd_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_11bcd_row0_col1, #T_11bcd_row1_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_11bcd_row0_col2, #T_11bcd_row0_col10, #T_11bcd_row8_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_11bcd_row0_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_11bcd_row0_col4, #T_11bcd_row7_col4, #T_11bcd_row8_col2, #T_11bcd_row13_col0, #T_11bcd_row13_col5, #T_11bcd_row13_col12 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_11bcd_row0_col5, #T_11bcd_row5_col7, #T_11bcd_row7_col12 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_11bcd_row0_col6, #T_11bcd_row1_col6, #T_11bcd_row2_col5, #T_11bcd_row2_col12, #T_11bcd_row4_col3, #T_11bcd_row4_col10, #T_11bcd_row6_col0, #T_11bcd_row6_col1, #T_11bcd_row6_col4, #T_11bcd_row6_col7, #T_11bcd_row8_col13, #T_11bcd_row11_col10, #T_11bcd_row12_col2, #T_11bcd_row12_col9, #T_11bcd_row13_col8, #T_11bcd_row13_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_11bcd_row0_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_11bcd_row0_col8, #T_11bcd_row3_col0, #T_11bcd_row9_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_11bcd_row0_col9, #T_11bcd_row7_col1, #T_11bcd_row10_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_11bcd_row0_col11, #T_11bcd_row0_col13, #T_11bcd_row5_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_11bcd_row0_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col2, #T_11bcd_row3_col12, #T_11bcd_row5_col8, #T_11bcd_row6_col2, #T_11bcd_row11_col12 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col3, #T_11bcd_row2_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_11bcd_row1_col4, #T_11bcd_row12_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_11bcd_row1_col7, #T_11bcd_row9_col0, #T_11bcd_row9_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_11bcd_row1_col8, #T_11bcd_row7_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_11bcd_row1_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col11, #T_11bcd_row3_col13, #T_11bcd_row8_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col12, #T_11bcd_row8_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_11bcd_row1_col13, #T_11bcd_row6_col5, #T_11bcd_row7_col13, #T_11bcd_row12_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_11bcd_row2_col1, #T_11bcd_row4_col9, #T_11bcd_row11_col6, #T_11bcd_row13_col2, #T_11bcd_row13_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col4, #T_11bcd_row5_col13, #T_11bcd_row11_col13, #T_11bcd_row13_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col7, #T_11bcd_row10_col1, #T_11bcd_row10_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_11bcd_row2_col8, #T_11bcd_row4_col6, #T_11bcd_row5_col2, #T_11bcd_row12_col13 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_11bcd_row2_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col11, #T_11bcd_row6_col10, #T_11bcd_row7_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_11bcd_row2_col13, #T_11bcd_row3_col4, #T_11bcd_row6_col3, #T_11bcd_row9_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_11bcd_row3_col1, #T_11bcd_row3_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_11bcd_row3_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_11bcd_row3_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_11bcd_row3_col6, #T_11bcd_row11_col7, #T_11bcd_row11_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_11bcd_row3_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_11bcd_row3_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_11bcd_row3_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_11bcd_row3_col11, #T_11bcd_row8_col6, #T_11bcd_row11_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col0, #T_11bcd_row4_col5, #T_11bcd_row5_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col1, #T_11bcd_row12_col1, #T_11bcd_row12_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col2, #T_11bcd_row9_col8, #T_11bcd_row11_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col7, #T_11bcd_row6_col12, #T_11bcd_row8_col11, #T_11bcd_row10_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col11 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_11bcd_row4_col13, #T_11bcd_row10_col4, #T_11bcd_row13_col7, #T_11bcd_row13_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_11bcd_row5_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_11bcd_row5_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_11bcd_row5_col3, #T_11bcd_row11_col5, #T_11bcd_row12_col0, #T_11bcd_row13_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_11bcd_row5_col6, #T_11bcd_row5_col9, #T_11bcd_row6_col9, #T_11bcd_row9_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_11bcd_row5_col10 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_11bcd_row5_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_11bcd_row6_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_11bcd_row6_col11, #T_11bcd_row9_col11, #T_11bcd_row9_col12, #T_11bcd_row10_col11, #T_11bcd_row12_col3, #T_11bcd_row12_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_11bcd_row6_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_11bcd_row7_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_11bcd_row7_col2, #T_11bcd_row7_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_11bcd_row7_col5, #T_11bcd_row8_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_11bcd_row7_col9 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_11bcd_row7_col10 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_11bcd_row7_col11, #T_11bcd_row9_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_11bcd_row8_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_11bcd_row8_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_11bcd_row8_col5, #T_11bcd_row11_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_11bcd_row8_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_11bcd_row8_col12 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_11bcd_row9_col1, #T_11bcd_row10_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_11bcd_row9_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_11bcd_row9_col7 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_11bcd_row9_col13, #T_11bcd_row12_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_11bcd_row10_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_11bcd_row10_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_11bcd_row10_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_11bcd_row10_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_11bcd_row10_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_11bcd_row10_col13, #T_11bcd_row11_col0, #T_11bcd_row12_col10 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_11bcd_row11_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_11bcd_row11_col4 {
#   back

# %% [markdown]
# ##### 3.2 Variable a predecir

# %% [markdown]
# Se crea una variable llamada "Resultado" que podrá tomar dos valores: P: Perdedor, G:Ganador. Teniendo en cuenta que inicialmente el jugador de referencia será "loser_name", la variable nueva tendrá el valor "P"

# %%
df_tenis["Resultado"]="P"

# %% [markdown]
# Se crean dos nuevos datasets, uno que contenga la información del jugador perdedor y otra con el ganador, compartiendo en ambos datasets las variables comunes a ambos en los partidos y que no dependen del desempeño del jugador en el encuentro como lo son: surface, tourney_level, y el nombre del oponente.

# %%
loser=df_tenis.rename(columns={"l_2ndWon":"J1_2ndWon","l_ace":"J1_ace","l_bpFaced":"J1_bpFaced","l_df":"J1_df","loser_age":"J1_age","loser_hand":"J1_hand","loser_ht":"J1_ht","loser_name":"J1_name","loser_rank":"J1_rank","w_2ndWon":"J2_2ndWon","w_ace":"J2_ace","w_bpFaced":"J2_bpFaced","w_df":"J2_df","winner_age":"J2_age","winner_hand":"J2_hand","winner_ht":"J2_ht","winner_name":"J2_name","winner_rank":"J2_rank"}) #Se cambian los nombres de las columnas y el jugador 1 siempre es el perdedor

winner=df_tenis.rename(columns={"l_2ndWon":"J2_2ndWon","l_ace":"J2_ace","l_bpFaced":"J2_bpFaced","l_df":"J2_df","loser_age":"J2_age","loser_hand":"J2_hand","loser_ht":"J2_ht","loser_name":"J2_name","loser_rank":"J2_rank","w_2ndWon":"J1_2ndWon","w_ace":"J1_ace","w_bpFaced":"J1_bpFaced","w_df":"J1_df","winner_age":"J1_age","winner_hand":"J1_hand","winner_ht":"J1_ht","winner_name":"J1_name","winner_rank":"J1_rank"}) #Se cambian los nombres de las columnas y a las columnas del winner se le asigna el nombre "J1" para concatener el dataframe con el de loser

winner["Resultado"]="G"  #Se asigna el valor de "G" a resultado ya que se invirtió el orden de los jugadores

# %% [markdown]
# Se concatenan los datasets para crear el conjunto completo donde se tendrá la variable a predecir y se convierten a entero aquellas variables que tenían un tipo flotante.

# %%
df_tenis= pd.concat([loser, winner]).reset_index().drop("index", axis=1) # Se concatenan los datasets y ya se tiene una variable objetivo "Resultado" que será la que se querrá predecir con el modelo

# Se convierten todas las columnas flotantes en enteras
df_tenis[['J1_2ndWon', 'J1_ace', 'J1_bpFaced', 'J1_df', 'J1_age', 'J1_ht', 'J2_2ndWon', 'J2_ace', 'J2_bpFaced', 'J2_df', 'J2_age', 'J2_ht',"J1_rank","J2_rank"]]=df_tenis[['J1_2ndWon', 'J1_ace', 'J1_bpFaced', 'J1_df', 'J1_age', 'J1_ht', 'J2_2ndWon', 'J2_ace', 'J2_bpFaced', 'J2_df', 'J2_age', 'J2_ht',"J1_rank","J2_rank"]].astype("int")

df_tenis.shape
# Out:
# (133430, 21)

# %% [markdown]
# ##### 3.2 Visualización de datos

# %% [markdown]
# Al duplicar la base de datos, si se grafica la variable a predecir "Resultado" se debe de contar con el mismo número de registros para las categorías "P" y "G"

# %%
df_tenis.groupby('Resultado').Resultado.count().sort_values(ascending=False)
plt.figure(figsize=(6,4))  

plt.title('Frecuencia de resultado total')
sns.countplot(x=df_tenis['Resultado'])

plt.show()

# %% [markdown]
# No osbtante, si se revisa la base de datos para un jugador específico la proporción es diferente.

# %%
federer=df_tenis[df_tenis["J1_name"]=="Roger Federer"]
plt.figure(figsize=(6,4))
plt.title('Frecuencia de resultado del jugador Roger Federer')
sns.countplot(x=federer['Resultado'])
labels = federer['Resultado'].unique()
for i, label in enumerate(labels):
    count = federer[federer['Resultado'] == label].shape[0]
    plt.text(i, count, str(count), ha='center')
plt.xticks(range(len(labels)), labels)
plt.show()

# %% [markdown]
# ##### 3.3 Variables categóricas

# %% [markdown]
# Se crea una variable que contenga únicamente las columnas categóricas de la base de datos, se crea una función para graficarlas y se revisa como se visualiza la distribución.

# %%
catCols=df_tenis.select_dtypes(include = ["object"]).columns.tolist() #Se crea la columna catCols que contiene las variables categóricas
catCols.remove('Resultado') # Se excluye la columna Resultado ya que es la variable a predecir.

# %%
#Función para graficar múltiples gráficas
def plot_multiples_graficas(df, cols, num_cols, num_rows, tipo, targetVar, figsize=(16,8)):
    
    plt.rcParams['figure.figsize'] = figsize
    
    #num_plots = len(cols)
    #num_cols = math.ceil(np.sqrt(num_plots))
    #num_rows = math.ceil(num_plots/num_cols)
        
    fig, axs = plt.subplots(num_rows, num_cols)
    
    for ind, col in enumerate(cols):
        i = math.floor(ind/num_cols)
        j = ind - i*num_cols
        
        if num_rows == 1:
            if num_cols == 1:
                if tipo == 'c': 
                    sns.countplot(x=df[col], ax=axs, dodge = False)
                if tipo == 'b':
                    sns.boxplot(x=df[col], y=df[targetVar], ax=axs)
                if tipo == 's':
                    sns.scatterplot(x=df[col], y=df[targetVar], ax=axs)
            else:
                if tipo == 'c':
                    sns.countplot(x=df[col], ax=axs[j], dodge = False)
                if tipo == 'b':
                    sns.boxplot(x=df[col], y=df[targetVar], ax=axs[j])
                if tipo == 's':
                    sns.scatterplot(x=df[col], y=df[targetVar], ax=axs[j])
        else:
            if num_cols == 1:
                if tipo == 'c':
                    sns.countplot(x=df[col], ax=axs[i], dodge = False)
                if tipo == 'b':
                    sns.boxplot(x=df[col], y=df[targetVar], ax=axs[i])
                if tipo == 's':
                    sns.scatterplot(x=df[col], y=df[targetVar], ax=axs[i])
            else:
                if tipo == 'c':
                    sns.countplot(x=df[col], ax=axs[i, j], dodge = False)
                if tipo == 'b':
                    sns.boxplot(x=df[col], y=df[targetVar], ax=axs[i, j])
                if tipo == 's':
                    sns.scatterplot(x=df[col], y=df[targetVar], ax=axs[i, j])

# %%
plot_multiples_graficas(df_tenis,catCols, 2, 3, 'c', None, (32,32))

# %% [markdown]
# Se evidencia que la mano dominante de los jugadores presenta tres clases: R (Right), L (Left) y U (Unknown). Se procede a verificar los registros que presentan la descripción "U"

# %%
print(df_tenis[df_tenis["J1_hand"]=="U"].shape)
print(df_tenis[df_tenis["J2_hand"]=="U"].shape)
# Out:
# (29, 21)
# (29, 21)

# %% [markdown]
# Se evidencian que son 29 registros con la descripción en "U" por lo que al ser tan poco representativos se decide eliminarlos de la base de datos.

# %%
df_tenis=df_tenis[(df_tenis["J1_hand"]!="U") & (df_tenis["J2_hand"]!="U")]

# %% [markdown]
# Asimismo, se evidencia que no es posible interpretar los gráficos de los nombres de jugadores debido a la gran cantidad de tenistas que han estado en el top100 durante el tiempo de medición y si se crean variable dummies con base en dicha columna, convertiría el dataset en una base con mas de mil columnas lo cual es muy dificil de procesar para un modelo. Por lo tanto y teniendo en cuenta que los jugadores se pueden identificar aún con la posición del ranking (rank) se decide eliminar los nombres de los jugadores de la base.

# %%
df_tenis.drop(["J1_name","J2_name"], axis=1, inplace=True)

# %%
copia=df_tenis.copy()

# %%
df_tenis=copia

# %% [markdown]
# #### 4. Creación de Variables Dummies

# %% [markdown]
# Con base en las columnas categóricas se crean las variables dummies para preparar la data para el modelo

# %%
# Aplicación de la función de usuario Dummies: one-hot encoding

df_tenis_dummie =pd.get_dummies(df_tenis, drop_first=1)
df_tenis_dummie.rename(columns={"Resultado_P":"Resultado"},inplace=True)
df_tenis_dummie["Resultado"].replace(1, "P", inplace=True)
df_tenis_dummie["Resultado"].replace(0, "G", inplace=True)

# %% [markdown]
# #### 5. Primera iteración

# %% [markdown]
# Se realizará una primera iteración del modelo escalando los datos de prueba y de entrenamiento y seleccionando los mejores parámetros que se obtienen con GridSearchCV

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Dividir los datos en conjuntos de entrenamiento y prueba (70/30)
X_train, X_test, y_train, y_test = train_test_split(df_tenis_dummie.drop('Resultado', axis=1), 
                                                    df_tenis_dummie['Resultado'], 
                                                    test_size=0.3, 
                                                    random_state=42)

# Escalar las características de los datos de entrenamiento y prueba
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Definir los parámetros que deseas ajustar y los valores que deseas probar
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

# Crear un objeto GridSearchCV y ajustarlo en los datos de entrenamiento
grid = GridSearchCV(LogisticRegression(), param_grid, cv=5, scoring='accuracy')
grid.fit(X_train_scaled, y_train)

# Obtener el mejor modelo encontrado
best_model = grid.best_estimator_

# Predecir en los datos de prueba usando el mejor modelo encontrado
y_pred = best_model.predict(X_test_scaled)

# %% [markdown]
# ##### 5.1. Resultados primera iteración

# %%
# Definir las etiquetas de las clases
labels = ['P', 'G']

# Obtener la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Visualizar la matriz de confusión
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"fontsize":20}, 
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted label', fontsize=18)
plt.ylabel('True label', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
# Calcular los indicadores de desempeño
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Imprimir los indicadores de desempeño
print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('Precision: {:.2f}%'.format(precision * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('F1-score: {:.2f}%'.format(f1 * 100))
# Out:
# Accuracy: 83.43%
# Precision: 83.44%
# Recall: 83.43%
# F1-score: 83.43%

# %%
# Obtener las probabilidades de clasificación para el conjunto de prueba
probs = best_model.predict_proba(X_test_scaled)
probs = probs[:, 1]  # Tomar la probabilidad de la clase positiva

# Obtener la curva ROC y el AUC
fpr, tpr, umbrales = roc_curve(y_test, probs, pos_label='P')
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'r--', label='Clasificador aleatorio')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de falsos positivos (FPR)', fontsize=16)
plt.ylabel('Tasa de verdaderos positivos (TPR)', fontsize=16)
plt.title('Curva ROC', fontsize=18)
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %% [markdown]
# #### 6. Segunda iteración - PCA

# %%
# Crear un objeto Pipeline que incluya el escalado, PCA y regresión logística
pipe = Pipeline([
    ('scaler', MinMaxScaler()),
    ('pca', PCA(n_components=2)),
    ('logistic', LogisticRegression(solver='liblinear'))
])

# Definir los parámetros que deseas ajustar y los valores que deseas probar
param_grid = {
    'pca__n_components': [2, 3, 4, 5, 10, 15],
    'logistic__C': [0.01, 0.1, 1, 10, 100],
    'logistic__penalty': ['l1', 'l2']
}

# Crear un objeto GridSearchCV y ajustarlo en los datos de entrenamiento
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train_scaled, y_train)

# Obtener el mejor modelo encontrado
best_model1 = grid.best_estimator_

# Predecir en los datos de prueba usando el mejor modelo encontrado
y_pred = best_model1.predict(X_test_scaled)

# %%
print(grid.best_params_)
# Out:
# {'logistic__C': 0.1, 'logistic__penalty': 'l1', 'pca__n_components': 15}

# %% [markdown]
# ##### 6.1. Resultados Segunda iteración

# %%
# Obtener la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Visualizar la matriz de confusión
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"fontsize":20}, 
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted label', fontsize=18)
plt.ylabel('True label', fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# Calcular los indicadores de desempeño
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Imprimir los indicadores de desempeño
print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('Precision: {:.2f}%'.format(precision * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('F1-score: {:.2f}%'.format(f1 * 100))
# Out:
# Accuracy: 79.81%
# Precision: 79.81%
# Recall: 79.81%
# F1-score: 79.81%

# %%
# Obtener las probabilidades de clasificación para el conjunto de prueba
probs = best_model1.predict_proba(X_test_scaled)
probs = probs[:, 1]  # Tomar la probabilidad de la clase positiva

# Obtener la curva ROC y el AUC
fpr, tpr, umbrales = roc_curve(y_test, probs, pos_label='P')
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'r--', label='Clasificador aleatorio')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de falsos positivos (FPR)', fontsize=16)
plt.ylabel('Tasa de verdaderos positivos (TPR)', fontsize=16)
plt.title('Curva ROC', fontsize=18)
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %%
# Obtener la varianza explicada de cada componente principal
var_exp = best_model1.named_steps['pca'].explained_variance_ratio_

# Crear la gráfica de barras
plt.figure(figsize=(8,6))
plt.bar(range(len(var_exp)), var_exp, color='#00BFFF')
plt.xlabel('Componentes principales', fontsize=16)
plt.ylabel('Varianza explicada', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Varianza explicada por componente principal', fontsize=18)
plt.show()
